# %% [markdown]
# # Q1

# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time
import numpy as np

# %%
driver=webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    
company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']//span")
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'Job_title':job_title,'Job_location':job_location,'Company_name':company_name,'Exp_required':experience_required})
df
# Out:
#                                            Job_title  \
# 0                             Senior Data Analyst II
# 1                               Project Data Analyst
# 2                     Data Analyst, Business Analyst
# 3                                       Data Analyst
# 4                           Executive - Data Analyst
# 5  Data Analyst / Product Analyst / Business Analyst
# 6        Senior Data Analyst - Data Modeling/Quality
# 7                                Senior Data Analyst
# 8                                  Sr . Data Analyst
# 9                                       Data Analyst
#
#                                         Job_location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                 Bangalore/Bengaluru(HSR Layout +1)
# 3                    Temp. WFH - Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                   Bangalore/Bengaluru, Delhi / NCR
# ...

# %% [markdown]
# # Q2

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title1=[]
job_location1=[]
company_name1=[]

# %%
title_tags1=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags1[0:10]:
    title1=i.text
    job_title1.append(title1)
    
location_tags1=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags1[0:10]:
    location1=i.text
    job_location1.append(location1)
    
company_tags1=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags1[0:10]:
    company1=i.text
    company_name1.append(company1)

# %%
print(len(job_title1),len(job_location1),len(company_name1))
# Out:
# 10 10 10

# %%
df1=pd.DataFrame({'Job_title':job_title1,'Job_location':job_location1,'Company_name':company_name1})
df1
# Out:
#                                            Job_title  \
# 0                   Analystics & Modeling Specialist
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3   ACN - Applied Intelligence - Data Scientist - 09
# 4                                     Data Scientist
# 5                                Data Scientist - II
# 6  Python Programming Language Data Science Pract...
# 7  ACN - Applied Intelligence - C4DI - Sustainabi...
# 8                                Lead Data Scientist
# 9                                Lead Data Scientist
#
#                                         Job_location      Company_name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...         Accenture
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...       Tata Nexarc
# 2                  Bangalore/Bengaluru, Nagpur, Pune     Tech Mahindra
# 3                                Bangalore/Bengaluru         Accenture
# ...

# %% [markdown]
# # Q3

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys('Delhi/NCR')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title2=[]
job_location2=[]
company_name2=[]
experience_required2=[]
salary_exp2=[]

# %%
title_tags2=driver.find_elements(By.XPATH,"//a[@class='title fw500 ellipsis']")
for i in title_tags2[0:10]:
    title2=i.text
    job_title2.append(title2)
    
location_tags2=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi location']")
for i in location_tags2[0:10]:
    location2=i.text
    job_location2.append(location2)
    
company_tags2=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags2[0:10]:
    company2=i.text
    company_name2.append(company2)
    
experience_tags2=driver.find_elements(By.XPATH,"//li[@class='fleft grey-text br2 placeHolderLi experience']//span")
for i in experience_tags2[0:10]:
    exp2=i.text
    experience_required2.append(exp2)
    
salary_tags2=driver.find_elements(By.XPATH,"//i[@class='fleft icon-16 lh16 mr-4 naukicon naukicon-rupee']")
for i in salary_tags2[0:10]:
    salary2=i.text
    salary_exp2.append(salary2)

# %%
print(len(job_title2),len(job_location2),len(company_name2),len(experience_required2),len(salary_exp2))
# Out:
# 10 10 10 10 10

# %%
df2=pd.DataFrame({'Job_title':job_title2,'Job_location':job_location2,'Company_name':company_name2,'Exp_required':experience_required2,'Salary_exp':salary_exp2})
df2
# Out:
#                                            Job_title  \
# 0                                     Data Scientist
# 1                                     Data Scientist
# 2                 Data Science - Engineering Manager
# 3  Artificial Intelligence/Computer Vision Engine...
# 4                                     Data Scientist
# 5  Hiring For DATA Scientist @ NTT DATA Business ...
# 6           Senior Data Scientist - Machine Learning
# 7                           Principal Data Scientist
# 8                  Data Scientist - R / Python / SQL
# 9  ACN - Applied Intelligence - Data & Insights -...
#
#                                         Job_location  \
# 0  Delhi / NCR, New Delhi, Hyderabad/Secunderabad...
# 1  Hybrid - Noida, Kolkata, Hyderabad/Secunderaba...
# 2                     New Delhi, Bangalore/Bengaluru
# 3  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 4                                     Hybrid - Noida
# 5  Noida, Hyderabad/Secunderabad, Pune, Gurgaon/G...
# ...

# %% [markdown]
# # Q4

# %%
driver.get("https://www.flipkart.com/")

# %%
item=driver.find_element(By.CLASS_NAME,"_3704LK")
item.send_keys('Sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
Brand_title=[]
Product_des=[]
Price=[]

# %%
for i in range(0,3):
    Brand_tags=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for i in Brand_tags:
        Brand1=i.text
        Brand_title.append(Brand1)
    
    Product_tags=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    for i in Product_tags:
        Product=i.text
        Product_des.append(Product)
    
    Price_tags=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
    for i in Price_tags:
        Price1=i.text
        Price.append(Price1)
    nxt_button=driver.find_elements(By.XPATH,"//a[@class='_1LKTO3']")
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))

# %%
sunglasses=pd.DataFrame({"Brand": Brand_title[:100],"Description": Product_des[:100],"Price": Price[:100]})
sunglasses
# Out:
#             Brand                                        Description Price
# 0      LIZA ANGEL  Riding Glasses, Night Vision Spectacle Sunglas...  ₹129
# 1        Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹489
# 2        Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹599
# 3      PHENOMENAL         UV Protection Retro Square Sunglasses (53)  ₹129
# 4       Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...  ₹149
# ..            ...                                                ...   ...
# 95        Urbanic                 Others Oval Sunglasses (Free Size)  ₹399
# 96  VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...  ₹949
# 97        Urbanic                 Others Oval Sunglasses (Free Size)  ₹549
# 98        DEIXELS  Polarized, UV Protection, Riding Glasses Wayfa...  ₹218
# 99       TheWhoop  UV Protection, Gradient Over-sized Sunglasses ...  ₹289
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q5

# %%
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
Rating=[]
Review_summ=[]
Full_rev=[]

# %%
for i in range(0,10):
    Rating_tags=driver.find_elements(By.XPATH,"//div[@class='_3LWZlK _1BLPMq']")
    for i in Rating_tags:
        Rating1=i.text
        Rating.append(Rating1)
    
    Review_tags=driver.find_elements(By.XPATH,"//p[@class='_2-N8zT']")
    for i in Review_tags:
        Review=i.text
        Review_summ.append(Review)
    
    Fullrev_tags=driver.find_elements(By.XPATH,"//div[@class='_27M-vq']")
    for i in Fullrev_tags:
        Fullrev=i.text
        Full_rev.append(Fullrev)
    nxt_button=driver.find_elements(By.XPATH,"//a[@class='_1LKTO3']")
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))

# %%
iphone=pd.DataFrame({"Ratings": Rating[:50],"Review": Review_summ[:50],"Full_Rev": Full_rev[:50]})
iphone
# Out:
#    Ratings                 Review  \
# 0        5         Simply awesome
# 1        5       Perfect product!
# 2        5    Best in the market!
# 3        4        Value-for-money
# 4        5      Worth every penny
# 5        5     Highly recommended
# 6        5     Highly recommended
# 7        5       Perfect product!
# 8        5          Great product
# 9        4            Pretty good
# 10       5              Fabulous!
# 11       5         Classy product
# 12       5     Highly recommended
# 13       5      Worth every penny
# 14       5       Perfect product!
# 15       4            Good choice
# 16       5       Perfect product!
# 17       5     Highly recommended
# 18       5       Perfect product!
# 19       5     Highly recommended
# 20       4        Value-for-money
# 21       5      Worth every penny
# 22       5       Perfect product!
# 23       5               Terrific
# 24       5         Simply awesome
# 25       5              Excellent
# ...

# %% [markdown]
# # Q6

# %%
driver.get("https://www.flipkart.com/")

# %%
item=driver.find_element(By.CLASS_NAME,"_3704LK")
item.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
Brand_title1=[]
Product_des1=[]
Price1=[]
Percent_off=[]

# %%
for i in range(0,3):
    Brand_tags1=driver.find_elements(By.XPATH,"//div[@class='_2WkVRV']")
    for i in Brand_tags1:
        Brand2=i.text
        Brand_title1.append(Brand2)
    
    Product_tags1=driver.find_elements(By.XPATH,"//a[@class='IRpwTa']")
    for i in Product_tags1:
        Product1=i.text
        Product_des1.append(Product1)
    
    Price_tags1=driver.find_elements(By.XPATH,"//div[@class='_30jeq3']")
    for i in Price_tags1:
        Price2=i.text
        Price1.append(Price2)
        
    Percentoff_tags1=driver.find_elements(By.XPATH,"//div[@class='_3Ay6Sb']")
    for i in Percentoff_tags1:
        Percentoff1=i.text
        Percent_off.append(Percentoff1)
    nxt_button=driver.find_elements(By.XPATH,"//a[@class='_1LKTO3']")
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))

# %%
sneaker=pd.DataFrame({"Brand": Brand_title1[:100],"Product": Product_des1[:100],"Price": Price1[:100],"Percentoff":Percent_off[:100]})
sneaker
# Out:
#         Brand                                            Product   Price  \
# 0   RED CHIEF                        RC3522 107 Sneakers For Men  ₹2,294
# 1   RED CHIEF                        RC3483 022 Sneakers For Men  ₹2,067
# 2      Labbin                                   Sneakers For Men    ₹399
# 3      Shozie                                   Sneakers For Men    ₹295
# 4        aadi  Mesh | Ultralightweight | Comfortable | Breath...    ₹359
# ..        ...                                                ...     ...
# 95   Roadster                                   Sneakers For Men    ₹899
# 96     Layasa                  Zora In Motion Sneakers For Women    ₹489
# 97     Layasa                  RAMBO-144LGR-ORG Sneakers For Men    ₹489
# 98   Elevarse                            SM-406 Sneakers For Men    ₹284
# 99   RED TAPE                          FUSE 80S Sneakers For Men  ₹1,039
#
#    Percentoff
# 0     55% off
# 1     55% off
# 2     60% off
# 3     70% off
# ...

# %% [markdown]
# # Q7

# %%
driver.get("https://www.amazon.in/")

# %%
item=driver.find_element(By.ID,"twotabsearchtextbox")
item.send_keys('laptop')

# %%
search=driver.find_element(By.ID,"nav-search-submit-text")
search.click()

# %%
Title2=[]
Ratings2=[]
Price2=[]

# %%
Title_tags2=driver.find_elements(By.XPATH,"//span[@class='a-size-medium a-color-base a-text-normal']")
for i in Title_tags2[0:10]:
    Title3=i.text
    Title2.append(Title3)

Ratings_tags2=driver.find_elements(By.XPATH,"//div[@class='a-row a-size-small']")
for i in Ratings_tags2[0:10]:
    Ratings3=i.text
    Ratings2.append(Ratings3)
    
Price_tags2=driver.find_elements(By.XPATH,"//span[@class='a-price-whole']")
for i in Price_tags2[0:10]:
    Price3=i.text
    Price2.append(Price3)

# %%
print(len(Title2),len(Ratings2),len(Price2))
# Out:
# 10 10 10

# %%
laptop=pd.DataFrame({'Title':Title2,'Ratings':Ratings2,'Price':Price2})
laptop
# Out:
#                                                Title     Ratings   Price
# 0  Acer Extensa Intel Core i3 11th Gen Intel Core...    3.0\n(2)  30,990
# 1  Lenovo IdeaPad Slim 1 AMD Ryzen 3 3250U 15.6" ...  4.0\n(269)  36,000
# 2  (Renewed) Dell Latitude E5470 Intel Core i5 6t...  3.6\n(511)  19,289
# 3  ASUS VivoBook 15 (2021), 15.6-inch (39.62 cm) ...  3.9\n(747)  25,990
# 4  Lenovo IdeaPad Slim 3 Intel Celeron N4020 4th ...  3.7\n(256)  27,990
# 5  Fujitsu UH-X 12th Gen Intel Evo Core i7 13.3 i...              99,990
# 6  HP 15s, AMD Athlon Silver 3050U 8GB RAM/512GB ...
# 7  HP 15s-Ryzen 3 3250U 8GB SDRAM/256GB SSD 15.6i...
# 8  AVITA SATUS ULTIMUS S111 NU14A1INC43PN-SG 14.1...
# 9  Lenovo V15 Intel Celeron N4020 15.6" (39.62 cm...

# %% [markdown]
# # Q8

# %%
driver.get("https://www.azquotes.com/top_quotes.html")

# %%
Quote=[]
Author=[]
Typeofquote=[]

# %%
for i in range(0,10):
    Quote_tags=driver.find_elements(By.XPATH,"//div[@class='wrap-block']")
    for i in Quote_tags:
        Quote1=i.text
        Quote.append(i.text.split('\n')[0])
    
    Author_tags=driver.find_elements(By.XPATH,"//div[@class='wrap-block']")
    for i in Author_tags:
        Author1=i.text
        Author.append(i.text.split('\n')[1])
    
    Type_tags=driver.find_elements(By.XPATH,"//div[@class='wrap-block']")
    for i in Type_tags:
        Type1=i.text
        Typeofquote.append(i.text.split('\n')[2])

# %%
AZ=pd.DataFrame({"Quotes": Quote[:1000],"Authors": Author[:1000],"TypeofQuotes": Typeofquote[:1000]})
AZ
# Out:
#                                                 Quotes               Authors  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
# ...

# %% [markdown]
# # Q9

# %%
driver.get("https://www.jagranjosh.com/general-knowledge/list-of-all-prime-ministers-of-india-1473165149-1")

# %%
Name=[]
Born_Dead=[]
Termofoffice=[]
Remark=[]

# %%
Name_tags=driver.find_elements(By.XPATH,"//div[@class='table-box']/table/tbody/tr/td[2]/p")
for i in Name_tags:
    Name1=i.text
    Name.append(Name1)
    
Borndead_tags=driver.find_elements(By.XPATH,"//div[@class='table-box']/table/tbody/tr/td[3]/p")
for i in Borndead_tags:
    Bornd1=i.text
    Born_Dead.append(Bornd1)

Term_tags=driver.find_elements(By.XPATH,"//div[@class='table-box']/table/tbody/tr/td[4]/p")
for i in Term_tags:
    Term1=i.text
    Termofoffice.append(Term1)
    
Remark_tags=driver.find_elements(By.XPATH,"//div[@class='table-box']/table/tbody/tr/td[5]/p")
for i in Remark_tags:
    Remark1=i.text
    Remark.append(Remark1)

# %%
PM=pd.DataFrame({"Names": Name[:18],"BornDead": Born_Dead[:18],"TermsOfOffice": Termofoffice[:18],"Remarks":Remark[:18]})
PM
# Out:
#                           Names      BornDead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                          TermsOfOffice  \
# ...

# %% [markdown]
# # Q10

# %%
driver.get("https://www.motor1.com/features/category/lists/")

# %%
expensivecars=driver.find_element(By.XPATH,"/html/body/div[3]/div[6]/form/div/input")
expensivecars.send_keys('50 most expensive cars in the world')

# %%
search=driver.find_element(By.CLASS_NAME,"features-search_input-submit")
search.click()

# %%
driver.get("https://www.motor1.com/features/308149/most-expensive-new-cars-ever/")

# %%
Carname=[]
Desc=[]
Price=[]

# %%
Car_tags=driver.find_elements(By.XPATH,"//h3[@class='subheader']")
for i in Car_tags:
    Car1=i.text
    Carname.append(Car1)
    
Desc_tags=driver.find_elements(By.XPATH,'/html/body/div[3]/div[7]/div[2]/div[1]/div[2]/div[1]/p')
for i in Desc_tags:
    Desc.append(i.text)
Desc_list=[]
for i in range(4,103,2):
    Desc_list.append(Desc[i])
    
Price_tags=driver.find_elements(By.XPATH,"//strong")
for i in Price_tags:
    Price.append(i.text)

# %%
EM=pd.DataFrame({"CarNames": Carname[:50],"Description": Desc_list[:50],"Prices": Price[:50]})
EM
# Out:
#                            CarNames  \
# 0                         Drako GTE
# 1                     De Tomaso P72
# 2                 Ferrari LaFerrari
# 3                     Pagani Huayra
# 4                      McLaren Elva
# 5                       Czinger 21C
# 6                     Ferrari Monza
# 7                Gordon Murray T.33
# 8                 Koenigsegg Gemera
# 9                       Zenvo TSR-S
# 10               Hennessey Venom F5
# 11                  Bentley Bacalar
# 12    Hispano Suiza Carmen Boulogne
# 13           Bentley Mulliner Batur
# 14                     Deus Vayanne
# 15                      SSC Tuatara
# 16                      Lotus Evija
# 17              Aston Martin Vulcan
# 18                       Delage D12
# 19                McLaren Speedtail
# 20                     Rimac Nevera
# 21                    Pagani Utopia
# 22             Pininfarina Battista
# 23                Ferrari FXX K Evo
# 24               Gordon Murray T.50
# ...
