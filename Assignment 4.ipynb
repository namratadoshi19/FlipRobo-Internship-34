# %%
# !pip install selenium
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException,ElementNotVisibleException
from selenium.webdriver.common.by import By
import time
import numpy as np
import urllib
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException,ElementNotInteractableException,SessionNotCreatedException,ElementClickInterceptedException
from geopy.geocoders import Nominatim

# %%
driver=webdriver.Chrome(r"C:\Users\User\Downloads\chromedriver_win32 (1)\chromedriver.exe")
driver.maximize_window()

# %% [markdown]
# # Q1

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
rank=[]
name=[]
artist=[]
upload_dt=[]
views=[]

# %%
RK_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[1]")
for i in RK_tags:
    RK1=i.text
    rank.append(RK1)
    
NM_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[2]")
for i in NM_tags:
    NM1=i.text
    name.append(NM1)

AR_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[3]")
for i in AR_tags:
    AR1=i.text
    artist.append(AR1)
    
UD_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[5]")
for i in UD_tags:
    UD1=i.text
    upload_dt.append(UD1)
    
VW_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[4]")
for i in VW_tags:
    VW1=i.text
    views.append(VW1)

# %%
YT=pd.DataFrame({"Rank": rank,"Name": name,"Artist": artist,"Upload_Date":upload_dt,"Views":views}).set_index("Rank")
YT
# Out:
#                                                  Name  \
# Rank
# 1.                              "Baby Shark Dance"[4]
# 2.                                     "Despacito"[7]
# 3.                         "Johny Johny Yes Papa"[14]
# 4.                                    "Bath Song"[15]
# 5.                                 "Shape of You"[16]
# 6.                                "See You Again"[18]
# 7.                  "Phonics Song with Two Words"[23]
# 8.                                  "Uptown Funk"[24]
# 9.    "Learning Colors – Colorful Eggs on a Farm"[25]
# 10.                           "Wheels on the Bus"[26]
# 11.                               "Gangnam Style"[27]
# 12.    "Masha and the Bear – Recipe for Disaster"[32]
# 13.                              "Dame Tu Cosita"[33]
# 14.                                       "Sugar"[34]
# 15.                                        "Roar"[35]
# 16.                              "Counting Stars"[36]
# ...

# %% [markdown]
# # Q2

# %%
driver.get("https://www.bcci.tv/")

# %%
time.sleep(5)
try:
    element=driver.find_element(By.XPATH,"//a[@class='nav-link active nav-link-fixtures']")
    element.click()
except ElementClickInterceptedException as e:
    print("Exception Raised: ",e)
    element=driver.find_element(By.XPATH,"//a[@class='nav-link active nav-link-fixtures']/li")
    print(element)
# Out:
# Exception Raised:  Message: element click intercepted: Element <a class="nav-link active nav-link-fixtures" data-tabtype="match-1">...</a> is not clickable at point (554, 23). Other element would receive the click: <div class="custom-container nav-top-main d-flex flex-wrap w-100">...</div>
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0067F243]
# 	(No symbol) [0x00607FD1]
# 	(No symbol) [0x004FD04D]
# 	(No symbol) [0x005328B9]
# 	(No symbol) [0x005308CC]
# 	(No symbol) [0x0052E4CB]
# 	(No symbol) [0x0052D164]
# 	(No symbol) [0x005232A6]
# 	(No symbol) [0x0054858C]
# 	(No symbol) [0x00522BFF]
# 	(No symbol) [0x00548804]
# 	(No symbol) [0x0055C9EB]
# 	(No symbol) [0x00548386]
# 	(No symbol) [0x0052163C]
# 	(No symbol) [0x0052269D]
# 	GetHandleVerifier [0x00919A22+2655074]
# 	GetHandleVerifier [0x0090CA24+2601828]
# 	GetHandleVerifier [0x00728C0A+619850]
# 	GetHandleVerifier [0x00727830+614768]
# 	(No symbol) [0x006105FC]
# ...

# %%
search=driver.find_element(By.XPATH,"//a[@class='moreMatchesLink']")
search.click()

# %%
odi=[]
series=[]
place=[]
date=[]
time=[]

# %%
OD_tags=driver.find_elements(By.XPATH,"//span[@class='ng-binding']")
for i in OD_tags:
    OD1=i.text
    odi.append(OD1)
    
PL_tags=driver.find_elements(By.XPATH,"//span[@class='ng-binding ng-scope']")
for i in PL_tags:
    PL1=i.text
    place.append(PL1)

DT_tags=driver.find_elements(By.XPATH,"//div[@class='match-card-left match-schedule']/h5")
for i in DT_tags:
    DT1=i.text
    date.append(DT1)
    
TM_tags=driver.find_elements(By.XPATH,"//h5[@class='text-right ng-binding']")
for i in TM_tags:
    TM1=i.text
    time.append(TM1)

# %%
IC=pd.DataFrame({"ODI": odi,"Place": place,"Date": date,"Time":time})
IC
# Out:
#                                                ODI  \
# 0   INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19
# 1   INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19
# 2   INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19
# 3       SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 4   INDIA WOMEN U19 TOUR OF SOUTH AFRICA WOMEN U19
# 5       SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 6       SRI LANKA TOUR OF INDIA T20 SERIES 2022-23
# 7       SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 8       SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 9       SRI LANKA TOUR OF INDIA ODI SERIES 2022-23
# 10    NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 11    NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 12    NEW ZEALAND TOUR OF INDIA ODI SERIES 2022-23
# 13    NEW ZEALAND TOUR OF INDIA T20 SERIES 2022-23
# 14    NEW ZEALAND TOUR OF INDIA T20 SERIES 2022-23
# 15    NEW ZEALAND TOUR OF INDIA T20 SERIES 2022-23
# 16     AUSTRALIA TOUR OF INDIA TEST SERIES 2022-23
# ...

# %% [markdown]
# # Q3

# %%
driver.get("https://www.guru99.com/")

# %%
try:
    element=driver.find_element(By.ID,"gs_tti50")
    element.click()
except NoSuchElementException as e:
    print("Exception Raised: ",e)
    element=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
    print(element)
# Out:
# Exception Raised:  Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="gs_tti50"]"}
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0067F243]
# 	(No symbol) [0x00607FD1]
# 	(No symbol) [0x004FD04D]
# 	(No symbol) [0x0052C0B0]
# 	(No symbol) [0x0052C22B]
# 	(No symbol) [0x0055E612]
# 	(No symbol) [0x005485D4]
# 	(No symbol) [0x0055C9EB]
# 	(No symbol) [0x00548386]
# 	(No symbol) [0x0052163C]
# 	(No symbol) [0x0052269D]
# 	GetHandleVerifier [0x00919A22+2655074]
# 	GetHandleVerifier [0x0090CA24+2601828]
# 	GetHandleVerifier [0x00728C0A+619850]
# 	GetHandleVerifier [0x00727830+614768]
# 	(No symbol) [0x006105FC]
# 	(No symbol) [0x00615968]
# 	(No symbol) [0x00615A55]
# 	(No symbol) [0x0062051B]
# 	BaseThreadInitThunk [0x77117D69+25]
# 	RtlInitializeExceptionChain [0x772EBB9B+107]
# 	RtlClearBits [0x772EBB1F+191]
# ---------------------------------------------------------------------------
# ...

# %%
item=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
item.send_keys('selenium exception handling')

# %%
search=driver.find_element(By.CLASS_NAME,"gsc-search-button")
search.click()

# %%
name=[]
desc=[]

# %%
NE_tags=driver.find_elements(By.XPATH,"//div[@class='gs-title']")
for i in NE_tags:
    NE1=i.text
    name.append(NE1)

DS_tags=driver.find_elements(By.XPATH,"//div[@class='gs-bidi-start-align gs-snippet']")
for i in DS_tags:
    DS1=i.text
    desc.append(DS1)

# %%
GC=pd.DataFrame({"Name": name,"Description": desc})
GC
# Out:
#                                                  Name  \
# 0    Exception Handling in Selenium Webdriver (Types)
# 1   How to Handle SSL Certificate in Selenium WebD...
# 2       Try Catch in Java: Exception Handling Example
# 3   Exception Handling in VB.Net: Try & Catch Hand...
# 4   C++ Exception Handling: Try, Catch, throw Example
# 5   Python Exception Handling: try, catch, finally...
# 6      Exception Handling in Oracle PL/SQL (Examples)
# 7   PHP Try Catch Example: Exception & Error Handl...
# 8           JSP Exception Handling: Error Page in JSP
# 9   Selenium Alert & Popup Window Handling: How to...
# 10
#
#                                           Description
# 0   29-Oct-2022 ... How to Handling Exceptions in ...
# 1   29-Oct-2022 ... For handling SSL certificate e...
# 2   05-Nov-2022 ... All these errors are highlight...
# 3   7 days ago ... In this VB.Net Exception Handli...
# 4   12-Nov-2022 ... Next, the exception handler wi...
# ...

# %% [markdown]
# # Q4

# %%
driver.get("https://www.statisticstimes.com/")

# %%
search=driver.find_element(By.XPATH,"//div[@class='navbar']/div[2]")
search.click()

# %%
search=driver.find_element(By.XPATH,"//div[@class='dropdown-content']/a[3]")
search.click()

# %%
search=driver.find_element(By.XPATH,"//div/div[2]/ul/li[1]/a[@class='ec']")
search.click()

# %%
rank1=[]
state=[]
gsdp18_19=[]
gsdp19_20=[]
share=[]
gdp=[]

# %%
RK1_tags=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
for i in RK1_tags:
    RK2=i.text
    rank1.append(RK2)

ST_tags=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
for i in ST_tags:
    ST1=i.text
    state.append(ST1)

GP_tags=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
for i in GP_tags:
    GP1=i.text
    gsdp18_19.append(GP1)

GP1_tags=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
for i in GP1_tags:
    GP2=i.text
    gsdp19_20.append(GP2)

SH_tags=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
for i in SH_tags:
    SH1=i.text
    share.append(SH1)
    
GD_tags=driver.find_elements(By.XPATH,"//div[@id='table_id_wrapper']/table/tbody/tr/td[6]")
for i in GD_tags:
    GD1=i.text
    gdp.append(GD1)

# %%
print(len(rank1),len(state),len(gsdp18_19),len(gsdp19_20),len(share),len(gdp))
# Out:
# 34 33 33 33 33 33

# %%
SW=pd.DataFrame({"Rank": rank1[:33],"State": state[:33],"GSDP18-19": gsdp18_19[:33],"GSDP19-20":gsdp19_20[:33],"Share":share[:33],"GDP":gdp[:33]}).set_index("Rank")
SW
# Out:
#                           State  GSDP18-19  GSDP19-20   Share      GDP
# Rank
# 1                   Maharashtra  2,632,792          -  13.94%  399.921
# 1                    Tamil Nadu  1,630,208  1,845,853   8.63%  247.629
# 2                 Uttar Pradesh  1,584,764  1,687,818   8.39%  240.726
# 3                       Gujarat  1,502,899          -   7.96%  228.290
# 4                     Karnataka  1,493,127  1,631,977   7.91%  226.806
# 5                   West Bengal  1,089,898  1,253,832   5.77%  165.556
# 6                     Rajasthan    942,586  1,020,989   4.99%  143.179
# 7                Andhra Pradesh    862,957    972,782   4.57%  131.083
# 8                     Telangana    861,031    969,604   4.56%  130.791
# 9                Madhya Pradesh    809,592    906,672   4.29%  122.977
# 10                       Kerala    781,653          -   4.14%  118.733
# 11                        Delhi    774,870    856,112   4.10%  117.703
# ...

# %% [markdown]
# # Q5

# %%
driver.get("https://github.com/")

# %%
time.sleep(5)
try:
    element=driver.find_element(By.XPATH,"//nav[@id='global-nav']/div/a[5]")
    element.click()
except NoSuchElementException as e:
    print("Exception Raised: ",e)
    element=driver.find_element(By.XPATH,"//a[@class='js-selected-navigation-item Header-link mt-md-n3 mb-md-n3 py-2 py-md-3 mr-0 mr-md-3 border-top border-md-top-0 border-white-fade']")
    print(element)
# Out:
# Exception Raised:  Message: no such element: Unable to locate element: {"method":"xpath","selector":"//nav[@id='global-nav']/div/a[5]"}
#   (Session info: chrome=108.0.5359.125)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0041F243]
# 	(No symbol) [0x003A7FD1]
# 	(No symbol) [0x0029D04D]
# 	(No symbol) [0x002CC0B0]
# 	(No symbol) [0x002CC22B]
# 	(No symbol) [0x002FE612]
# 	(No symbol) [0x002E85D4]
# 	(No symbol) [0x002FC9EB]
# 	(No symbol) [0x002E8386]
# 	(No symbol) [0x002C163C]
# 	(No symbol) [0x002C269D]
# 	GetHandleVerifier [0x006B9A22+2655074]
# 	GetHandleVerifier [0x006ACA24+2601828]
# 	GetHandleVerifier [0x004C8C0A+619850]
# 	GetHandleVerifier [0x004C7830+614768]
# 	(No symbol) [0x003B05FC]
# 	(No symbol) [0x003B5968]
# 	(No symbol) [0x003B5A55]
# 	(No symbol) [0x003C051B]
# 	BaseThreadInitThunk [0x77117D69+25]
# 	RtlInitializeExceptionChain [0x772EBB9B+107]
# 	RtlClearBits [0x772EBB1F+191]
# ---------------------------------------------------------------------------
# ...

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/header/div[3]/nav/a[5]")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/main/div[1]/nav/div/a[3]")
search.click()

# %%
title=[]
des=[]
count=[]
lang=[]

# %%
product_urls=[]
start=0
end=1
for page in range(start,end):
    url=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]/a')
    for i in url:
        product_urls.append(i.get_attribute("href"))

# %%
for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        TT=driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div/main/div/div[1]/div/div/strong/a')
        title.append(TT.text)
    except NoSuchElementException:
        title.append("-")
        
for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        DS=driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div/main/turbo-frame/div/div/div/div[3]/div[2]/div/div[1]/div/p')
        des.append(DS.text)
    except NoSuchElementException:
        des.append("-")
        
for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        CT=driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div/main/turbo-frame/div/div/div/div[3]/div[2]/div/div[5]/div/h2/a')
        count.append(CT.text)
    except NoSuchElementException:
        count.append("-")
        
for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    try:
        LG=driver.find_element(By.XPATH,'//span[@class="color-fg-default text-bold mr-1"]')
        lang.append(LG.text)
    except NoSuchElementException:
        lang.append("-")

# %%
print(len(title),len(des),len(count),len(lang))
# Out:
# 25 25 25 25

# %%
GH=pd.DataFrame({"Rep_title": title,"Rep_des": des,"Cont_count": count,"Lang_used":lang})
GH
# Out:
#                     Rep_title  \
# 0             Reactive-Resume
# 1              awesome-python
# 2      awesome-english-ebooks
# 3              Open-Assistant
# 4                    cramming
# 5                  javascript
# 6           PaLM-rlhf-pytorch
# 7   chinese-independent-blogs
# 8                      arthas
# 9                     Flipper
# 10                   ai-notes
# 11                  microfeed
# 12                 CodeFormer
# 13                       IPTV
# 14                     unocss
# 15                     server
# 16                  gpt_index
# 17                osv-scanner
# 18                    upscayl
# 19    awesome-design-patterns
# 20                    ChatGPT
# 21                      Atlas
# 22                     strapi
# 23                HelloGitHub
# 24                       curl
#
#                                               Rep_des        Cont_count  \
# 0   A one-of-a-kind resume builder that keeps your...   Contributors 84
# ...

# %% [markdown]
# # Q6

# %%
driver.get("https://www.billboard.com/")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a")
search.click()

# %%
sname=[]
art=[]
lwrank=[]
prank=[]
weeks=[]

# %%
SN_tags=driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[1]")
for i in SN_tags:
    SN1=i.text
    sname.append(SN1)
    
AT_tags=driver.find_elements(By.XPATH,"//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only']")
for i in AT_tags:
    AT1=i.text
    art.append(AT1)
    
LR_tags=driver.find_elements(By.XPATH,"//li[@class='o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max']/span")
for i in LR_tags:
    LR1=i.text
    lwrank.append(LR1)
    
PK_tags=driver.find_elements(By.XPATH,"//li[@class='o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max']/span")
for i in PK_tags:
    PK1=i.text
    prank.append(PK1)
    
WK_tags=driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[6]/span")
for i in WK_tags:
    WK1=i.text
    weeks.append(WK1)

# %%
print(len(sname),len(art),len(lwrank),len(prank),len(weeks))
# Out:
# 100 99 200 100 100

# %%
BS=pd.DataFrame({'Song_Name':sname[:99],'Artist_Name':art[:99],'Last_wk_rank':lwrank[:99],'Peak_Rank':prank[:99],'Weeks_on_chart':weeks[:99]})
BS
# Out:
#                                         Song_Name  \
# 0   All I Want For Christmas Is You\nMariah Carey
# 1   Rockin' Around The Christmas Tree\nBrenda Lee
# 2                   Jingle Bell Rock\nBobby Helms
# 3              A Holly Jolly Christmas\nBurl Ives
# 4                           Last Christmas\nWham!
# ..                                            ...
# 94                                 Conceited\nSZA
# 95                        Down Home\nJimmie Allen
# 96             One Thing At A Time\nMorgan Wallen
# 97    Hold Me Closer\nElton John & Britney Spears
# 98                                       Far\nSZA
#
#                     Artist_Name Last_wk_rank Peak_Rank Weeks_on_chart
# 0                    Brenda Lee            1         1             57
# 1                   Bobby Helms           57         2             51
# 2                     Burl Ives            2         3             48
# 3                         Wham!           51         4             31
# ...

# %% [markdown]
# # Q7

# %%
driver.get("https://www.naukri.com/hr-recruiters-consultants")

# %%
designation=driver.find_element(By.CLASS_NAME,"sugInp")
designation.send_keys('Data Science')

# %%
search=driver.find_element(By.ID,"qsbFormBtn")
search.click()

# %%
name=[]
desg=[]
comp=[]
skills=[]
loc=[]

# %%
NM_tags=driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']")
for i in NM_tags:
    NM1=i.text
    name.append(NM1)
    
DS_tags=driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']")
for i in DS_tags:
    DS1=i.text
    desg.append(DS1)
    
CM_tags=driver.find_elements(By.XPATH,"/html/body/div[3]/div/div[2]/div/div[2]/div/div/div[1]/div[1]/p/a[2]")
for i in CM_tags:
    CM1=i.text
    comp.append(CM1)
    
SK_tags=driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']")
for i in SK_tags:
    SK1=i.text
    skills.append(SK1)
    
LC_tags=driver.find_elements(By.XPATH,"//small[@class='ellipsis']")
for i in LC_tags:
    LC1=i.text
    loc.append(LC1)

# %%
print(len(name),len(desg),len(comp),len(skills),len(loc))
# Out:
# 50 50 50 50 48

# %%
NK=pd.DataFrame({'Name':name[:48],'Designation':desg[:48],'Company':comp[:48],'Skills':skills[:48],'Location':loc[:48]})
NK
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                             Mahesh Babu Channa
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Vaishnavi Kudalkar
# 15                                 Priyanka Akiri
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %% [markdown]
# # Q8

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
book=[]
author=[]
volume=[]
publ=[]
gen=[]

# %%
BK_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[2]")
for i in BK_tags:
    BK1=i.text
    book.append(BK1)
    
AT_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[3]")
for i in AT_tags:
    AT1=i.text
    author.append(AT1)

VE_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[4]")
for i in VE_tags:
    VE1=i.text
    volume.append(VE1)
    
PB_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[5]")
for i in PB_tags:
    PB1=i.text
    publ.append(PB1)
    
GN_tags=driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[6]")
for i in GN_tags:
    GN1=i.text
    gen.append(GN1)

# %%
BS=pd.DataFrame({'Book_Name':book,'Author':author,'Volumes_sold':volume,'Publisher':publ,'Genre':gen})
BS
# Out:
#                                             Book_Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes_sold        Publisher                        Genre
# ...

# %% [markdown]
# # Q9

# %%
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
name=[]
yrspan=[]
genr=[]
runtm=[]
rat=[]
vote=[]

# %%
NM_tags=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a")
for i in NM_tags:
    NM1=i.text
    name.append(NM1)
    
YR_tags=driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/span[2]")
for i in YR_tags:
    YR1=i.text
    yrspan.append(YR1)
    
GR_tags=driver.find_elements(By.XPATH,"//p[@class='text-muted text-small']/span[5]")
for i in GR_tags:
    GR1=i.text
    genr.append(GR1)
    
RT_tags=driver.find_elements(By.XPATH,"//p[@class='text-muted text-small']/span[3]")
for i in RT_tags:
    RT1=i.text
    runtm.append(RT1)
    
RG_tags=driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']/span[2]")
for i in RG_tags:
    RG1=i.text
    rat.append(RG1)
    
VT_tags=driver.find_elements(By.XPATH,"//p[@class='text-muted text-small']/span[2]")
for i in VT_tags:
    VT1=i.text
    vote.append(VT1)
vote1=vote[1::2]

# %%
print(len(name),len(yrspan),len(genr),len(runtm),len(rat),len(vote1))
# Out:
# 100 100 100 100 100 100

# %%
IM=pd.DataFrame({'Movie_Name':name,'Yr_Span':yrspan,'Genre':genr,'Run_time':runtm,'Ratings':rat,'Vote':vote1})
IM
# Out:
#                         Movie_Name      Yr_Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds     (2005– )     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time Ratings       Vote
# 0    57 min     9.2  2,099,265
# ...

# %% [markdown]
# # Q10

# %%
driver.get("https://archive.ics.uci.edu/")

# %%
search=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
search.click()

# %%
dtname=[]
dttype=[]
tsk=[]
attri=[]
inst=[]
noatt=[]
yr=[]

# %%
DN_tags=driver.find_elements(By.XPATH,"//p[@class='normal']/b/a")
for i in DN_tags:
    DN1=i.text
    dtname.append(DN1)
    
DT_tags=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p")
for i in DT_tags:
    DT1=i.text
    dttype.append(DT1)
dttype1=dttype[1::]

TK_tags=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p")
for i in TK_tags:
    TK1=i.text
    tsk.append(TK1)
tsk1=tsk[1::]

AT_tags=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p")
for i in AT_tags:
    AT1=i.text
    attri.append(AT1)
attri1=attri[1::]

IT_tags=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p")
for i in IT_tags:
    IT1=i.text
    inst.append(IT1)
inst1=inst[1::]

AR_tags=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p")
for i in AR_tags:
    AR1=i.text
    noatt.append(AR1)
noatt1=noatt[1::]

YR_tags=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p")
for i in YR_tags:
    YR1=i.text
    yr.append(YR1)
yr1=yr[1::]

# %%
print(len(dtname),len(dttype1),len(tsk1),len(attri1),len(inst1),len(noatt1),len(yr1))
# Out:
# 622 622 622 622 622 622 622

# %%
DS=pd.DataFrame({'Databse_Name':dtname,'Data_type':dttype1,'Task':tsk1,'Attribute_type':attri1,'NoofInstances':inst1,'NoofAttribute':noatt1,'Year':yr1})
DS
# Out:
#                                           Databse_Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data_type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
